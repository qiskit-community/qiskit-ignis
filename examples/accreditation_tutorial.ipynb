# %% [markdown]
# <img src="../../../images/qiskit_header.png" alt="Note: In order for images to show up in this jupyter notebook you need to select File => Trusted Notebook" align="middle">

# %% [markdown]
# # Accreditation protocol

# %% [markdown]
# Accreditation Protocol (AP) is a protocol devised to characterize the reliability of noisy quantum devices.<br>
#
# Given a noisy quantum device implementing a "target" quantum circuit, AP certifies an upper-bound on the variation distance between the probability distribution of the outputs returned by the device and the ideal probability distribution.
# This method is based on Ferracin et al, "Accrediting outputs of noisy intermediate-scale quantum devices", https://arxiv.org/abs/1811.09709.
#
# This notebook gives an example for how to use the ignis.characterization.accreditation module. This particular example shows how to accredit the outputs of a 4-qubit quantum circuit of depth 5. All the circuits are run using the noisy Aer simulator.

# %%
#Import general libraries (needed for functions)
import numpy as np
from numpy import random
import qiskit

#Import Qiskit classes
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister, Aer, execute
from qiskit.providers.aer.noise import NoiseModel
from qiskit.providers.aer.noise.errors.standard_errors import depolarizing_error

#Import the accreditation functions.
from qiskit.ignis.verification.accreditation import accreditationFitter,accreditationCircuits

# %% [markdown]
# # Input to the protocol

# %% [markdown]
# AP can accredit the outputs of a __target circuit__ that<br>
# 1) Takes as input $n$ qubits in the state $|{0}>$<br>
# 2) Ends with single-qubit measurements in the Pauli-$Z$ basis<br>
# 3) Is made of $m$ "bands", each band containing a round of single-qubit gates and a round of controlled-$Z$ gates.<br>
# The accreditation is made by employing __trap circuits__, circuits that can be efficiently simulated on a classical computer and that whose outputs are used to witness the correct functionality of the device.<br>
#
# Let's now draw a target quantum circuit!
# We start with a simple circuit to generate and measure 4-qubits GHZ states.

# %%
# Create a Quantum Register with n_qb qubits.
q_reg = QuantumRegister(4, 'q')
# Create a Classical Register with n_qb bits.
c_reg = ClassicalRegister(4, 's')
# Create a Quantum Circuit acting on the q register
target_circuit = QuantumCircuit(q_reg, c_reg)

target_circuit.h(0)
target_circuit.h(1)
target_circuit.h(2)
target_circuit.h(3)
target_circuit.cz(0,1)
target_circuit.cz(0,2)
target_circuit.h(1)
target_circuit.h(2)
target_circuit.cz(0,3)
target_circuit.cz(1,2)
target_circuit.h(1)
target_circuit.h(2)
target_circuit.h(3)

target_circuit.measure(q_reg, c_reg)

target_circuit.draw(output = 'mpl')

# %% [markdown]
# # Generating accreditation circuits

# %% [markdown]
# The function $accreditation\_circuits$ generates all the circuits required by AP, target and traps. It automatically appends random Pauli gates to the circuits (if the implementation is noisy, these random Pauli gates reduce the noise to Pauli errors ! ) <br>
#
# It also returns the list $postp\_list$ of strings required to post-process the outputs, as well as the number $v\_zero$ indicating the circuit implementing the target.
#
# This is the target circuit with randomly chosen Pauli gates:

# %%
accsys = accreditationCircuits(target_circuit)

v = 10

circ_list, postp_list, v_zero = accsys.generateCircuits(v)
circ_list[(v_zero)%(v+1)].draw(output = 'mpl')

# %% [markdown]
# This is how a trap looks like:

# %%
circ_list[(v_zero+1)%(v+1)].draw(output = 'mpl')

# %% [markdown]
# One can use the optional twoqubitgate arguement to switch use cx instead of cz gates and can arbitrarily change the coupling map, in order to compile to the desired device topology (which in this case might lead to more layers than expected).

# %%
accsys.targetCircuit(target_circuit, twoqubitgate='cx', coupling_map=[[0,1],[1,2],[2,3]] )

v = 10

circ_list, postp_list, v_zero = accsys.generateCircuits(v)
circ_list[(v_zero)%(v+1)].draw(output = 'mpl')

# %% [markdown]
# # Simulate the ideal circuits

# %% [markdown]
# Let's implement AP.
#
# We use $accreditation\_circuits$ to generate target and trap circuits.
# Then, we use the function $single\_protocol\_run$ to implement all these circuits, keeping the output of the target only if all of the traps return the correct output.

# %%
simulator = qiskit.Aer.get_backend('qasm_simulator')

test_1 = accreditationFitter()

# Create target and trap circuits with random Pauli gates
circuit_list, postp_list, v_zero = accsys.generateCircuits(v)

outputs_list = []
for circ in circuit_list:
    job = execute(circ, simulator,
                  shots=1)
    outputs_list.append(job.result())

# Post-process the outputs and see if the protocol accepts
test_1.single_protocol_run(outputs_list, postp_list, v_zero)

print("Outputs of the target: ",test_1.outputs," , AP",test_1.flag,"these outputs!")
# Out:
# Outputs of the target:  ['1001']  , AP accepted these outputs!

# %% [markdown]
# In the absence of noise, all traps return the expected output, therefore we always accept the output of the target.<br>
#
# To obtain an upper-bound on the variation distance on the outputs of the target circuit, we need to implement AP $d$ times, each time with ___v___ different trap circuits.

# %%
# Number of runs
d = 100

test_2 = accreditationFitter()

for run in range(d):
    
    # Create target and trap circuits with random Pauli gates
    circuit_list, postp_list, v_zero = accsys.generateCircuits(v)
    
    outputs_list = []
    # Implement all these circuits
    for circuit_k in range(v+1):
        job = execute(circuit_list[circuit_k], simulator,
                      shots=1)
        outputs_list.append(job.result())

    # Post-process the outputs and see if the protocol accepts
    test_2.single_protocol_run(outputs_list, postp_list, v_zero)
    print("Protocol run number",run+1,", outputs of the target",test_2.flag)
    
print('\nAfter',test_2.num_runs,'runs, AP has accepted',test_2.N_acc,'outputs!')

print('\nList of accepted outputs:\n', test_2.outputs)
# Out:
# Protocol run number 1 , outputs of the target accepted
# Protocol run number 2 , outputs of the target accepted
# Protocol run number 3 , outputs of the target accepted
# Protocol run number 4 , outputs of the target accepted
# Protocol run number 5 , outputs of the target accepted
# Protocol run number 6 , outputs of the target accepted
# Protocol run number 7 , outputs of the target accepted
# Protocol run number 8 , outputs of the target accepted
# Protocol run number 9 , outputs of the target accepted
# Protocol run number 10 , outputs of the target accepted
# Protocol run number 11 , outputs of the target accepted
# Protocol run number 12 , outputs of the target accepted
# Protocol run number 13 , outputs of the target accepted
# Protocol run number 14 , outputs of the target accepted
# Protocol run number 15 , outputs of the target accepted
# Protocol run number 16 , outputs of the target accepted
# Protocol run number 17 , outputs of the target accepted
# Protocol run number 18 , outputs of the target accepted
# Protocol run number 19 , outputs of the target accepted
# Protocol run number 20 , outputs of the target accepted
# Protocol run number 21 , outputs of the target accepted
# Protocol run number 22 , outputs of the target accepted
# Protocol run number 23 , outputs of the target accepted
# Protocol run number 24 , outputs of the target accepted
# Protocol run number 25 , outputs of the target accepted
# Protocol run number 26 , outputs of the target accepted
# Protocol run number 27 , outputs of the target accepted
# Protocol run number 28 , outputs of the target accepted
# Protocol run number 29 , outputs of the target accepted
# Protocol run number 30 , outputs of the target accepted
# Protocol run number 31 , outputs of the target accepted
# Protocol run number 32 , outputs of the target accepted
# Protocol run number 33 , outputs of the target accepted
# Protocol run number 34 , outputs of the target accepted
# Protocol run number 35 , outputs of the target accepted
# Protocol run number 36 , outputs of the target accepted
# Protocol run number 37 , outputs of the target accepted
# Protocol run number 38 , outputs of the target accepted
# Protocol run number 39 , outputs of the target accepted
# Protocol run number 40 , outputs of the target accepted
# Protocol run number 41 , outputs of the target accepted
# Protocol run number 42 , outputs of the target accepted
# Protocol run number 43 , outputs of the target accepted
# Protocol run number 44 , outputs of the target accepted
# Protocol run number 45 , outputs of the target accepted
# Protocol run number 46 , outputs of the target accepted
# Protocol run number 47 , outputs of the target accepted
# Protocol run number 48 , outputs of the target accepted
# Protocol run number 49 , outputs of the target accepted
# Protocol run number 50 , outputs of the target accepted
# Protocol run number 51 , outputs of the target accepted
# Protocol run number 52 , outputs of the target accepted
# Protocol run number 53 , outputs of the target accepted
# Protocol run number 54 , outputs of the target accepted
# Protocol run number 55 , outputs of the target accepted
# Protocol run number 56 , outputs of the target accepted
# Protocol run number 57 , outputs of the target accepted
# Protocol run number 58 , outputs of the target accepted
# Protocol run number 59 , outputs of the target accepted
# Protocol run number 60 , outputs of the target accepted
# Protocol run number 61 , outputs of the target accepted
# Protocol run number 62 , outputs of the target accepted
# Protocol run number 63 , outputs of the target accepted
# Protocol run number 64 , outputs of the target accepted
# Protocol run number 65 , outputs of the target accepted
# Protocol run number 66 , outputs of the target accepted
# Protocol run number 67 , outputs of the target accepted
# Protocol run number 68 , outputs of the target accepted
# Protocol run number 69 , outputs of the target accepted
# Protocol run number 70 , outputs of the target accepted
# Protocol run number 71 , outputs of the target accepted
# Protocol run number 72 , outputs of the target accepted
# Protocol run number 73 , outputs of the target accepted
# Protocol run number 74 , outputs of the target accepted
# Protocol run number 75 , outputs of the target accepted
# Protocol run number 76 , outputs of the target accepted
# Protocol run number 77 , outputs of the target accepted
# Protocol run number 78 , outputs of the target accepted
# Protocol run number 79 , outputs of the target accepted
# Protocol run number 80 , outputs of the target accepted
# Protocol run number 81 , outputs of the target accepted
# Protocol run number 82 , outputs of the target accepted
# Protocol run number 83 , outputs of the target accepted
# Protocol run number 84 , outputs of the target accepted
# Protocol run number 85 , outputs of the target accepted
# Protocol run number 86 , outputs of the target accepted
# Protocol run number 87 , outputs of the target accepted
# Protocol run number 88 , outputs of the target accepted
# Protocol run number 89 , outputs of the target accepted
# Protocol run number 90 , outputs of the target accepted
# Protocol run number 91 , outputs of the target accepted
# Protocol run number 92 , outputs of the target accepted
# Protocol run number 93 , outputs of the target accepted
# Protocol run number 94 , outputs of the target accepted
# Protocol run number 95 , outputs of the target accepted
# Protocol run number 96 , outputs of the target accepted
# Protocol run number 97 , outputs of the target accepted
# Protocol run number 98 , outputs of the target accepted
# Protocol run number 99 , outputs of the target accepted
# Protocol run number 100 , outputs of the target accepted
#
# After 100 runs, AP has accepted 100 outputs!
#
# List of accepted outputs:
#  ['1001', '1001', '0110', '1001', '0100', '1101', '1111', '1111', '0100', '0100', '1111', '0110', '0000', '0100', '1111', '0000', '0000', '1011', '1001', '0000', '1101', '0000', '1001', '1011', '0000', '0110', '0100', '0010', '0100', '0000', '1001', '1011', '1101', '1101', '1001', '1001', '0010', '1111', '1011', '1011', '0000', '0000', '1111', '0000', '1111', '1111', '0010', '1001', '0010', '0100', '1101', '1111', '1001', '0000', '1101', '1111', '0100', '1011', '1101', '1001', '0100', '0000', '1001', '1011', '1101', '1001', '1101', '1001', '0000', '0010', '0110', '0010', '1011', '0000', '0110', '0100', '0000', '1111', '1111', '1101', '1111', '0010', '0100', '1011', '0000', '0110', '0000', '0100', '0100', '0010', '1101', '1101', '1001', '0110', '1001', '1001', '0000', '1011', '0000', '1001', '1101']

# %% [markdown]
# The function $bound\_variation\_distance$ calculates the upper-bound on the variation distance (VD) using
#
# $$VD\leq \frac{\varepsilon}{N_{\textrm{acc}}/d-\theta}\textrm{ ,}$$
#
# where $\theta\in[0,1]$ is a positive number and<br>
#
# $$\varepsilon= \frac{1.7}{v+1}$$
#
# is the maximum probability of accepting an incorrect state for the target.<br>
# The function $bound\_variation\_distance$ also calculates the confidence in the bound as
#
# $$1-2\textrm{exp}\big(-2\theta d^2\big)$$

# %%
theta = 5/100

test_2.bound_variation_distance(theta)

print("AP accepted",test_2.N_acc,"out of",test_2.num_runs,"times.")
print("With confidence",test_2.confidence,"AP certifies that VD is upper-bounded by",test_2.bound)
# Out:
# AP accepted 100 out of 100 times.
# With confidence 1.0 AP certifies that VD is upper-bounded by 0.16267942583732053

# %% [markdown]
# # Defining the noise model

# %% [markdown]
# We define a noise model for the simulator. We add depolarizing error probabilities to the cotrolled-$Z$ and single-qubit gates.

# %%
noise_model = NoiseModel()

p1q = 0.003
noise_model.add_all_qubit_quantum_error(depolarizing_error(p1q, 1), 'u1')
noise_model.add_all_qubit_quantum_error(depolarizing_error(p1q, 1), 'u2')
noise_model.add_all_qubit_quantum_error(depolarizing_error(p1q, 1), 'u3')
p2q = 0.03
noise_model.add_all_qubit_quantum_error(depolarizing_error(p2q, 2), 'cz')

basis_gates = ['u1','u2','u3','cz']

# %% [markdown]
# We then implement noisy circuits and pass their outputs to $single\_protocol\_run$.

# %%
test_3 = accreditationFitter()

for run in range(d):
    
    # Create target and trap circuits with random Pauli gates
    circuit_list, postp_list, v_zero = accsys.generateCircuits(v)
    
    outputs_list = []
    # Implement all these circuits with noise
    for circuit in circuit_list:
        job = execute(circuit, simulator,
                      noise_model=noise_model, basis_gates=basis_gates,
                      shots=1)
        outputs_list.append(job.result())

    # Post-process the outputs and see if the protocol accepts
    test_3.single_protocol_run(outputs_list, postp_list, v_zero)
    print("Protocol run number",run+1,", outputs of the target",test_3.flag)
  
print("\nAP accepted",test_3.N_acc,"out of",test_3.num_runs,"times.")
print('\nList of accepted outputs:\n', test_3.outputs)

theta = 5/100

test_3.bound_variation_distance(theta)
print("\nWith confidence",test_3.confidence,"AP certifies that VD is upper-bounded by",test_3.bound)
# Out:
# Protocol run number 1 , outputs of the target rejected
# Protocol run number 2 , outputs of the target accepted
# Protocol run number 3 , outputs of the target rejected
# Protocol run number 4 , outputs of the target accepted
# Protocol run number 5 , outputs of the target rejected
# Protocol run number 6 , outputs of the target rejected
# Protocol run number 7 , outputs of the target accepted
# Protocol run number 8 , outputs of the target rejected
# Protocol run number 9 , outputs of the target rejected
# Protocol run number 10 , outputs of the target accepted
# Protocol run number 11 , outputs of the target accepted
# Protocol run number 12 , outputs of the target rejected
# Protocol run number 13 , outputs of the target rejected
# Protocol run number 14 , outputs of the target accepted
# Protocol run number 15 , outputs of the target accepted
# Protocol run number 16 , outputs of the target accepted
# Protocol run number 17 , outputs of the target rejected
# Protocol run number 18 , outputs of the target rejected
# Protocol run number 19 , outputs of the target accepted
# Protocol run number 20 , outputs of the target rejected
# Protocol run number 21 , outputs of the target rejected
# Protocol run number 22 , outputs of the target rejected
# Protocol run number 23 , outputs of the target rejected
# Protocol run number 24 , outputs of the target rejected
# Protocol run number 25 , outputs of the target rejected
# Protocol run number 26 , outputs of the target rejected
# Protocol run number 27 , outputs of the target accepted
# Protocol run number 28 , outputs of the target accepted
# Protocol run number 29 , outputs of the target rejected
# Protocol run number 30 , outputs of the target accepted
# Protocol run number 31 , outputs of the target rejected
# Protocol run number 32 , outputs of the target accepted
# Protocol run number 33 , outputs of the target rejected
# Protocol run number 34 , outputs of the target rejected
# Protocol run number 35 , outputs of the target rejected
# Protocol run number 36 , outputs of the target rejected
# Protocol run number 37 , outputs of the target rejected
# Protocol run number 38 , outputs of the target rejected
# Protocol run number 39 , outputs of the target rejected
# Protocol run number 40 , outputs of the target accepted
# Protocol run number 41 , outputs of the target accepted
# Protocol run number 42 , outputs of the target accepted
# Protocol run number 43 , outputs of the target accepted
# Protocol run number 44 , outputs of the target rejected
# Protocol run number 45 , outputs of the target accepted
# Protocol run number 46 , outputs of the target rejected
# Protocol run number 47 , outputs of the target accepted
# Protocol run number 48 , outputs of the target accepted
# Protocol run number 49 , outputs of the target rejected
# Protocol run number 50 , outputs of the target rejected
# Protocol run number 51 , outputs of the target rejected
# Protocol run number 52 , outputs of the target rejected
# Protocol run number 53 , outputs of the target accepted
# Protocol run number 54 , outputs of the target rejected
# Protocol run number 55 , outputs of the target accepted
# Protocol run number 56 , outputs of the target rejected
# Protocol run number 57 , outputs of the target accepted
# Protocol run number 58 , outputs of the target rejected
# Protocol run number 59 , outputs of the target rejected
# Protocol run number 60 , outputs of the target rejected
# Protocol run number 61 , outputs of the target accepted
# Protocol run number 62 , outputs of the target accepted
# Protocol run number 63 , outputs of the target rejected
# Protocol run number 64 , outputs of the target rejected
# Protocol run number 65 , outputs of the target rejected
# Protocol run number 66 , outputs of the target rejected
# Protocol run number 67 , outputs of the target accepted
# Protocol run number 68 , outputs of the target rejected
# Protocol run number 69 , outputs of the target accepted
# Protocol run number 70 , outputs of the target accepted
# Protocol run number 71 , outputs of the target rejected
# Protocol run number 72 , outputs of the target accepted
# Protocol run number 73 , outputs of the target rejected
# Protocol run number 74 , outputs of the target rejected
# Protocol run number 75 , outputs of the target rejected
# Protocol run number 76 , outputs of the target accepted
# Protocol run number 77 , outputs of the target accepted
# Protocol run number 78 , outputs of the target rejected
# Protocol run number 79 , outputs of the target accepted
# Protocol run number 80 , outputs of the target accepted
# Protocol run number 81 , outputs of the target rejected
# Protocol run number 82 , outputs of the target accepted
# Protocol run number 83 , outputs of the target rejected
# Protocol run number 84 , outputs of the target rejected
# Protocol run number 85 , outputs of the target accepted
# Protocol run number 86 , outputs of the target accepted
# Protocol run number 87 , outputs of the target rejected
# Protocol run number 88 , outputs of the target rejected
# Protocol run number 89 , outputs of the target accepted
# Protocol run number 90 , outputs of the target accepted
# Protocol run number 91 , outputs of the target rejected
# Protocol run number 92 , outputs of the target accepted
# Protocol run number 93 , outputs of the target accepted
# Protocol run number 94 , outputs of the target rejected
# Protocol run number 95 , outputs of the target rejected
# Protocol run number 96 , outputs of the target rejected
# Protocol run number 97 , outputs of the target rejected
# Protocol run number 98 , outputs of the target rejected
# Protocol run number 99 , outputs of the target rejected
# Protocol run number 100 , outputs of the target rejected
#
# AP accepted 40 out of 100 times.
#
# List of accepted outputs:
#  ['1001', '1001', '0110', '1001', '0100', '1101', '1111', '1111', '0100', '0100', '1111', '0110', '0000', '0100', '1111', '0000', '0000', '1011', '1001', '0000', '1101', '0000', '1001', '1011', '0000', '0110', '0100', '0010', '0100', '0000', '1001', '1011', '1101', '1101', '1001', '1001', '0010', '1111', '1011', '1011', '0000', '0000', '1111', '0000', '1111', '1111', '0010', '1001', '0010', '0100', '1101', '1111', '1001', '0000', '1101', '1111', '0100', '1011', '1101', '1001', '0100', '0000', '1001', '1011', '1101', '1001', '1101', '1001', '0000', '0010', '0110', '0010', '1011', '0000', '0110', '0100', '0000', '1111', '1111', '1101', '1111', '0010', '0100', '1011', '0000', '0110', '0000', '0100', '0100', '0010', '1101', '1101', '1001', '0110', '1001', '1001', '0000', '1011', '0000', '1001', '1101', '1101', '0100', '0000', '1011', '0010', '1101', '1111', '0110', '0000', '0000', '0110', '1111', '1001', '0000', '1101', '0000', '1111', '0100', '1101', '1001', '1111', '1101', '0010', '1000', '1110', '1111', '0000', '0000', '1101', '1111', '1001', '1111', '1111', '0110', '0000', '1001', '1011', '1001', '1011', '0101']
#
# With confidence 1.0 AP certifies that VD is upper-bounded by 0.4415584415584415

# %% [markdown]
# Changing the number of trap circuits per protocol run changes the upper-bound on the VD, but not the confidence.<br>
#
# What number of trap circuits will ensure the minimal upper-bound for your target circuit?

# %%
min_traps = 4
max_traps = 10


for num_trap_circs in range(min_traps,max_traps): 
    
    test_4 = accreditationFitter()
    for run in range(d):

        # Create target and trap circuits with random Pauli gates
        circuit_list, postp_list, v_zero = accsys.generateCircuits(num_trap_circs)

        outputs_list = []
        # Implement all these circuits with noise
        for circuit in circuit_list:
            job = execute(circuit, simulator,
                          noise_model=noise_model, basis_gates=basis_gates,
                          shots=1)
            outputs_list.append(job.result())

        # Post-process the outputs and see if the protocol accepts
        test_4.single_protocol_run(outputs_list, postp_list, v_zero)

    print("\nWith", num_trap_circs,
          "traps, AP accepted", test_4.N_acc,              
          "out of", test_4.num_runs, "times.")
    test_4.bound_variation_distance(theta)
    print("With confidence", test_4.confidence,
          "AP with", num_trap_circs,
          "traps certifies that VD is upper-bounded by", test_4.bound)
# Out:
# With 4 traps, AP accepted 57 out of 100 times.
# With confidence 1.0 AP with 4 traps certifies that VD is upper-bounded by 0.6538461538461537
#
# With 5 traps, AP accepted 76 out of 100 times.
# With confidence 1.0 AP with 5 traps certifies that VD is upper-bounded by 0.39906103286384975
#
# With 6 traps, AP accepted 62 out of 100 times.
# With confidence 1.0 AP with 6 traps certifies that VD is upper-bounded by 0.42606516290726826
#
# With 7 traps, AP accepted 38 out of 100 times.
# With confidence 1.0 AP with 7 traps certifies that VD is upper-bounded by 0.643939393939394
#
# With 8 traps, AP accepted 33 out of 100 times.
# With confidence 1.0 AP with 8 traps certifies that VD is upper-bounded by 0.6746031746031744
#
# With 9 traps, AP accepted 32 out of 100 times.
# With confidence 1.0 AP with 9 traps certifies that VD is upper-bounded by 0.6296296296296295
