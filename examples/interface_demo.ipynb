# %%
import sys, os
sys.path.append(os.path.abspath(os.path.join('../qiskit_ignis')))

from qiskit import QuantumRegister, QuantumCircuit, ClassicalRegister
from qiskit.tools.visualization.interactive import iplot_state
import tomography
from tomography.interface import perform_state_tomography

# %%
q3 = QuantumRegister(3)
circuit = QuantumCircuit(q3)
circuit.h(q3[2])

# %%
rho = perform_state_tomography(circuit, q3)
iplot_state(rho)
# Out:
#     <p>
#         <div id="content_15446254765351157" style="position: absolute; z-index: 1;">
#             <div id="cities_15446254765351157"></div>
#         </div>
#     </p>
#
#     <script>
#         requirejs.config({
#             paths: {
#                 qVisualization: "https://qvisualization.mybluemix.net/q-visualizations"
#             }
#         });
#
#         require(["qVisualization"], function(qVisualizations) {
#             data = {
# ...

# %%
q2 = [q3[0], q3[1]]
rho = perform_state_tomography(circuit, q2)
iplot_state(rho)
# Out:
#     <p>
#         <div id="content_15446254770651689" style="position: absolute; z-index: 1;">
#             <div id="cities_15446254770651689"></div>
#         </div>
#     </p>
#
#     <script>
#         requirejs.config({
#             paths: {
#                 qVisualization: "https://qvisualization.mybluemix.net/q-visualizations"
#             }
#         });
#
#         require(["qVisualization"], function(qVisualizations) {
#             data = {
#                 real: [[0.9993789895145089, -0.0027792678793128896, 0.0007207038122731262, 0.038303148687631836], [-0.0026832616975847176, 0.0013520441583609534, -9.911720688822832e-05, -0.000123031520577812], [0.0007155944050163802, -1.6827525872240207e-05, 0.0018499910252423961, 5.481568610984664e-05], [0.03829819858724574, -0.00012635623342315306, -2.0836534462477552e-05, -0.00235026114032645]],
#                 titleReal: "Real.[rho]",
# ...
